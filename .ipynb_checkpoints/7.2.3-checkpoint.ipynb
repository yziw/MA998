# %%
using Plots

# %%
logistic(z) = 1 ./ (1 .+exp.(-z))
# Out:
# logistic (generic function with 1 method)

# %%
w1, w2 = 8.0, -8.0

ns = 10
x = 4*rand(ns) .-1
z = x*w1 .+ w2
t = rand(ns) .< logistic(z)

xx = collect(-1:0.01:3)
zz = xx*w1 .+ w2
ff = logistic(zz)
# Out:
# 401-element Array{Float64,1}:
#  1.12535162055095e-7
#  1.2190788457038122e-7
#  1.3206123346184165e-7
#  1.4306022477689817e-7
#  1.5497528955294558e-7
#  1.6788272481495226e-7
#  1.8186518213514908e-7
#  1.9701219688321032e-7
#  2.1342076155588578e-7
#  2.3119594685727992e-7
#  2.5045157450675526e-7
#  2.713109460826215e-7
#  2.939076325686218e-7
#  ⋮
#  0.999999728689054
#  0.9999997495484255
#  0.9999997688040531
#  0.9999997865792385
#  0.9999998029878032
#  0.999999818134818
#  0.9999998321172752
#  0.9999998450247105
#  0.9999998569397752
#  0.9999998679387666
#  0.9999998780921155
#  0.9999998874648379

# %%
plot(xx, ff)
scatter!(x, t)
